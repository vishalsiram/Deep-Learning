# %% [markdown]
# # Fake News Classification using LSTM

# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#    id                                              title              author  \
# 0   0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1   1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2   2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3   3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4   4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
df.describe()
# Out:
#                  id         label
# count  20800.000000  20800.000000
# mean   10399.500000      0.500625
# std     6004.587135      0.500012
# min        0.000000      0.000000
# 25%     5199.750000      0.000000
# 50%    10399.500000      1.000000
# 75%    15599.250000      1.000000
# max    20799.000000      1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20800 entries, 0 to 20799
# Data columns (total 5 columns):
# id        20800 non-null int64
# title     20242 non-null object
# author    18843 non-null object
# text      20761 non-null object
# label     20800 non-null int64
# dtypes: int64(2), object(3)
# memory usage: 812.6+ KB

# %%
df=df.dropna()#drop the Nan Values

# %%
df.isnull().sum()
# Out:
# id        0
# title     0
# author    0
# text      0
# label     0
# dtype: int64

# %%
df.tail()
# Out:
#           id                                              title  \
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 20795                              Jerome Hudson
# 20796                           Benjamin Hoffman
# 20797  Michael J. de la Merced and Rachel Abrams
# 20798                                Alex Ansary
# 20799                              David Swanson
#
#                                                     text  label
# 20795  Rapper T. I. unloaded on black celebrities who...      0
# 20796  When the Green Bay Packers lost to the Washing...      0
# 20797  The Macy’s of today grew from the union of sev...      0
# ...

# %%
df2= df.drop(['id'], axis = 1)

# %%
df2.head()
# Out:
#                                                title              author  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...       Darrell Lucus
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...     Daniel J. Flynn
# 2                  Why the Truth Might Get You Fired  Consortiumnews.com
# 3  15 Civilians Killed In Single US Airstrike Hav...     Jessica Purkiss
# 4  Iranian woman jailed for fictional unpublished...      Howard Portnoy
#
#                                                 text  label
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...      1
# 1  Ever get the feeling your life circles the rou...      0
# 2  Why the Truth Might Get You Fired October 29, ...      1
# 3  Videos 15 Civilians Killed In Single US Airstr...      1
# 4  Print \nAn Iranian woman has been sentenced to...      1

# %%
from sklearn import preprocessing

# %%
df2.dropna()
# Out:
#        title                                             author  \
# 0       7002                                      Darrell Lucus
# 1       5380                                    Daniel J. Flynn
# 2      17017                                 Consortiumnews.com
# 3        119                                    Jessica Purkiss
# 4       7845                                     Howard Portnoy
# 5       8142                                    Daniel Nussbaum
# 7       2017                                    Alissa J. Rubin
# 9        441                       Megan Twohey and Scott Shane
# 10     10630                                        Aaron Klein
# 11      1730                                    Chris Tomlinson
# 12     12553                                      Amando Flavio
# 13     15904                                         Jason Ditz
# 14     11911                                       AnotherAnnie
# 15      7591                                      Jack Williams
# ...

# %%
df2.isnull().sum()
# Out:
# title     0
# author    0
# text      0
# label     0
# dtype: int64

# %%
# label_encoder object knows how to understand word labels. 
label_encoder = preprocessing.LabelEncoder()

# %%
# Encode labels in column 'species'. 
df2['title']= label_encoder.fit_transform(df2['title']) 
df2['title'].unique()
# Out:
# array([ 7002,  5380, 17017, ...,  9893,  9152,  9936], dtype=int64)

# %%
df2
# Out:
#        title                                             author  \
# 0       7002                                      Darrell Lucus
# 1       5380                                    Daniel J. Flynn
# 2      17017                                 Consortiumnews.com
# 3        119                                    Jessica Purkiss
# 4       7845                                     Howard Portnoy
# 5       8142                                    Daniel Nussbaum
# 7       2017                                    Alissa J. Rubin
# 9        441                       Megan Twohey and Scott Shane
# 10     10630                                        Aaron Klein
# 11      1730                                    Chris Tomlinson
# 12     12553                                      Amando Flavio
# 13     15904                                         Jason Ditz
# 14     11911                                       AnotherAnnie
# 15      7591                                      Jack Williams
# ...

# %%
df2['author']= label_encoder.fit_transform(df2['author']) 
df2['author'].unique()
# Out:
# array([ 887,  858,  783, ...,  805, 1839, 2448], dtype=int64)

# %%
df2['text']= label_encoder.fit_transform(df2['text']) 
df2['text'].unique()
# Out:
# array([ 7109,  5593, 17003, ..., 13791,  9431,   430], dtype=int64)

# %%
df2.head(2)
# Out:
#    title  author  text  label
# 0   7002     887  7109      1
# 1   5380     858  5593      0

# %%
X= df2.drop(['label'], axis=True)

# %%
X
# Out:
#        title  author   text
# 0       7002     887   7109
# 1       5380     858   5593
# 2      17017     783  17003
# 3        119    1655  15469
# 4       7845    1396  11578
# 5       8142     864   7664
# 7       2017     192  10697
# 9        441    2360   2092
# 10     10630      39  10599
# 11      1730     711  13587
# 12     12553     223  14378
# 13     15904    1566   4386
# 14     11911     376  17202
# 15      7591    1499   6521
# 16     16578    2403  14512
# 17      1324    3281   1610
# 18      5304    3396   5647
# 19      3109    1593  16628
# 21      9728    1643  12547
# 22     12352    2758  13189
# 24       820    1000  10589
# 25     10443    1436   5430
# 26      4892      40   7997
# 27      7309     220   7177
# 28      1255    1662   2620
# 29      7087    2249   6824
# 30      3105    1415   5184
# 32      6571    3315   8446
# 33     13928     764   8934
# 34      1974    2103   4941
# ...      ...     ...    ...
# 20766  11448    2834  11401
# ...

# %%
y=df2.label

# %%
y
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
# 5        0
# 7        0
# 9        0
# 10       0
# 11       0
# 12       1
# 13       1
# 14       1
# 15       0
# 16       0
# 17       1
# 18       1
# 19       0
# 21       0
# 22       0
# 24       0
# 25       1
# 26       0
# 27       1
# 28       0
# 29       0
# 30       0
# 32       0
# 33       0
# 34       0
#         ..
# 20766    0
# 20767    1
# 20769    1
# 20770    1
# 20773    1
# 20774    0
# 20775    1
# 20776    1
# 20777    1
# 20778    0
# 20779    0
# 20780    0
# 20781    1
# 20782    1
# 20783    0
# 20784    1
# 20785    0
# 20787    0
# 20788    1
# 20789    0
# 20790    0
# 20791    1
# 20792    0
# 20793    1
# 20794    0
# 20795    0
# 20796    0
# 20797    0
# 20798    1
# 20799    1
# Name: label, Length: 18285, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
Lg=LogisticRegression()

# %%
Lg.fit(X_train,y_train)
# Out:
# C:\Users\vishal\AppData\Local\Continuum\anaconda3\envs\data_S\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='warn', n_jobs=None, penalty='l2',
#                    random_state=None, solver='warn', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
Lg.score(X_test,y_test)
# Out:
# 0.5940347970173985

# %%
df.tail()
# Out:
#           id                                              title  \
# 20795  20795  Rapper T.I.: Trump a ’Poster Child For White S...
# 20796  20796  N.F.L. Playoffs: Schedule, Matchups and Odds -...
# 20797  20797  Macy’s Is Said to Receive Takeover Approach by...
# 20798  20798  NATO, Russia To Hold Parallel Exercises In Bal...
# 20799  20799                          What Keeps the F-35 Alive
#
#                                           author  \
# 20795                              Jerome Hudson
# 20796                           Benjamin Hoffman
# 20797  Michael J. de la Merced and Rachel Abrams
# 20798                                Alex Ansary
# 20799                              David Swanson
#
#                                                     text  label
# 20795  Rapper T. I. unloaded on black celebrities who...      0
# 20796  When the Green Bay Packers lost to the Washing...      0
# 20797  The Macy’s of today grew from the union of sev...      0
# ...

# %%
df2.head()
# Out:
#    title  author   text  label
# 0   7002     887   7109      1
# 1   5380     858   5593      0
# 2  17017     783  17003      1
# 3    119    1655  15469      1
# 4   7845    1396  11578      1

# %%
a=Lg.predict([[119,1655,15469]])

# %%
if a==0:
    print("fake")
else:
    print("real")
# Out:
# fake
